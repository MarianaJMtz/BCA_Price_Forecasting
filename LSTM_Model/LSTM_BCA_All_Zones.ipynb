# %% [markdown]
# ## All zones analysis
#
# Here, we used the function developed previously to build a LSTM Recurrent Neural Network for each of Baja California's zones.

# %%
from LSTM_Model_Function import LSTM_LMP

# %% [markdown]
# ### Ensenada

# %%
LSTM_LMP("ENSENADA")
# Out:
# Using TensorFlow backend.
# Epoch 1/19
# 25620/25620 [==============================] - 172s - loss: 0.0026 - mean_absolute_error: 0.0212
# Epoch 2/19
# 25620/25620 [==============================] - 164s - loss: 0.0017 - mean_absolute_error: 0.0165
# Epoch 3/19
# 25620/25620 [==============================] - 166s - loss: 0.0014 - mean_absolute_error: 0.0144
# Epoch 4/19
# 25620/25620 [==============================] - 163s - loss: 0.0012 - mean_absolute_error: 0.0136
# Epoch 5/19
# 25620/25620 [==============================] - 165s - loss: 0.0011 - mean_absolute_error: 0.0132
# Epoch 6/19
# 25620/25620 [==============================] - 165s - loss: 0.0011 - mean_absolute_error: 0.0129
# Epoch 7/19
# 25620/25620 [==============================] - 164s - loss: 0.0011 - mean_absolute_error: 0.0127
# Epoch 8/19
# 25620/25620 [==============================] - 165s - loss: 0.0011 - mean_absolute_error: 0.0123
# Epoch 9/19
# ...

# %% [markdown]
# ### Tijuana

# %%
LSTM_LMP("TIJUANA")
# Out:
# Epoch 1/19
# 25620/25620 [==============================] - 170s - loss: 0.0028 - mean_absolute_error: 0.0207
# Epoch 2/19
# 25620/25620 [==============================] - 166s - loss: 0.0019 - mean_absolute_error: 0.0165
# Epoch 3/19
# 25620/25620 [==============================] - 164s - loss: 0.0014 - mean_absolute_error: 0.0141
# Epoch 4/19
# 25620/25620 [==============================] - 172s - loss: 0.0012 - mean_absolute_error: 0.0125
# Epoch 5/19
# 25620/25620 [==============================] - 175s - loss: 0.0012 - mean_absolute_error: 0.0131
# Epoch 6/19
# 25620/25620 [==============================] - 167s - loss: 0.0011 - mean_absolute_error: 0.0124
# Epoch 7/19
# 25620/25620 [==============================] - 170s - loss: 0.0011 - mean_absolute_error: 0.0121
# Epoch 8/19
# 25620/25620 [==============================] - 168s - loss: 0.0011 - mean_absolute_error: 0.0123
# Epoch 10/19
# ...

# %% [markdown]
# ### San Luis

# %%
LSTM_LMP("SANLUIS")
# Out:
# Using TensorFlow backend.
# Epoch 1/19
# 25620/25620 [==============================] - 169s - loss: 0.0029 - mean_absolute_error: 0.0214
# Epoch 2/19
# 25620/25620 [==============================] - 163s - loss: 0.0017 - mean_absolute_error: 0.0158
# Epoch 3/19
# 25620/25620 [==============================] - 164s - loss: 0.0014 - mean_absolute_error: 0.0141
# Epoch 4/19
# 25620/25620 [==============================] - 164s - loss: 0.0012 - mean_absolute_error: 0.0132
# Epoch 5/19
# 25620/25620 [==============================] - 162s - loss: 0.0011 - mean_absolute_error: 0.0124
# Epoch 6/19
# 25620/25620 [==============================] - 173s - loss: 0.0011 - mean_absolute_error: 0.0122
# Epoch 7/19
# 25620/25620 [==============================] - 168s - loss: 0.0010 - mean_absolute_error: 0.0122
# Epoch 9/19
# 25620/25620 [==============================] - 166s - loss: 0.0010 - mean_absolute_error: 0.0117
# Epoch 10/19
# ...

# %% [markdown]
# ### Mexicali

# %%
LSTM_LMP("MEXICALI")
# Out:
# Using TensorFlow backend.
# Epoch 1/19
# 25620/25620 [==============================] - 144s - loss: 0.0028 - mean_absolute_error: 0.0212
# Epoch 2/19
# 25620/25620 [==============================] - 195s - loss: 0.0018 - mean_absolute_error: 0.0160
# Epoch 3/19
# 25620/25620 [==============================] - 215s - loss: 0.0012 - mean_absolute_error: 0.0131
# Epoch 5/19
# 25620/25620 [==============================] - 147s - loss: 0.0010 - mean_absolute_error: 0.0126
# Epoch 6/19
# 25620/25620 [==============================] - 137s - loss: 0.0011 - mean_absolute_error: 0.0121
# Epoch 7/19
# 25620/25620 [==============================] - 136s - loss: 0.0010 - mean_absolute_error: 0.0121
# Epoch 8/19
# 25620/25620 [==============================] - 137s - loss: 9.7539e-04 - mean_absolute_error: 0.0117
# Epoch 9/19
# 25620/25620 [==============================] - 136s - loss: 9.4843e-04 - mean_absolute_error: 0.0116
# Epoch 10/19
# ...
