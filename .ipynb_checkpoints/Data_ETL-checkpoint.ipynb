# %%
#Import dependencies
import pandas as pd
import numpy as np
import datetime
import requests
import json
import os

# %%
#Get the dates from 27 January 2016 to 01 May 2019 

first_dates = pd.date_range(start='2016-01-27', end='2019-05-01', freq='7D')
end_dates = pd.date_range(start='2016-02-02', end='2019-05-10', freq='7D')

# %%
#Create empy lists to store data retrieved from API
Zonas_MDA = []
Fechas_MDA = []
Horas_MDA = []
pz_MDA = []
pz_ene_MDA = []
pz_per_MDA = []
pz_cng_MDA = []

# %%
#Make call to CENACE's API "SW-PEND"

number=len(first_dates)

for i in range(number):
    
    if i == number-1:
        DUNO = str(first_dates[i])
        DUNO = DUNO.replace(" 00:00:00", "")
        DDOS = DUNO
        THOURS = 24 #Hours in a day
    
    else:
        DUNO = str(first_dates[i])
        DUNO = DUNO.replace(" 00:00:00", "")
        DDOS = str(end_dates[i])
        DDOS = DDOS.replace(" 00:00:00", "")
        THOURS= 168 #Hours in a week

    url= "https://ws01.cenace.gob.mx:8082/SWPEND/SIM/BCA/MDA/ENSENADA,MEXICALI,SANLUIS,TIJUANA/"+DUNO+"/"+DDOS+"/JSON"
    url_new= url.replace("-","/")

    response = requests.get(url_new)
    response_JSON = response.json()
    
    if response_JSON["status"] == "OK":
        
        for Z in range(4):
            
            for HORA in range(THOURS):
                
                Zonas_MDA.append(response_JSON["Resultados"][Z]["zona_carga"])
                
                try:
                    Fechas_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["fecha"])
                    
                except: 
                    Fechas_MDA.append(np.nan)
                    
                try: 
                    Horas_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["hora"])
                    
                except: 
                    Horas_MDA.append(np.nan)
                    
                try:
                    pz_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["pz"])
                    
                except:
                    pz_MDA.append(np.nan)
                    
                try:
                    pz_ene_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["pz_ene"])
                    
                except:
                    pz_ene_MDA.append(np.nan)
                    
                try:
                    pz_per_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["pz_per"])
                    
                except:
                    pz_per_MDA.append(np.nan)
                    
                try:
                    pz_cng_MDA.append(response_JSON["Resultados"][Z]["Valores"][HORA]["pz_cng"])
                    
                except:
                    pz_cng_MDA.append(np.nan)
                    
    print("Processing: MDA | BCA | START:" + DUNO + " | END: " + DDOS)
    
    i=i+1
    
print("-----------------------------------------------------------------------------------------")
print("                         EXTRACTION PROCESS FINISHED                                     ")
print("-----------------------------------------------------------------------------------------")
# Out:
# Processing: MDA | BCA | START:2016-01-27 | END: 2016-02-02
# Processing: MDA | BCA | START:2016-02-03 | END: 2016-02-09
# Processing: MDA | BCA | START:2016-02-10 | END: 2016-02-16
# Processing: MDA | BCA | START:2016-02-17 | END: 2016-02-23
# Processing: MDA | BCA | START:2016-02-24 | END: 2016-03-01
# Processing: MDA | BCA | START:2016-03-02 | END: 2016-03-08
# Processing: MDA | BCA | START:2016-03-09 | END: 2016-03-15
# Processing: MDA | BCA | START:2016-03-16 | END: 2016-03-22
# Processing: MDA | BCA | START:2016-03-23 | END: 2016-03-29
# Processing: MDA | BCA | START:2016-03-30 | END: 2016-04-05
# Processing: MDA | BCA | START:2016-04-06 | END: 2016-04-12
# Processing: MDA | BCA | START:2016-04-13 | END: 2016-04-19
# Processing: MDA | BCA | START:2016-04-20 | END: 2016-04-26
# Processing: MDA | BCA | START:2016-04-27 | END: 2016-05-03
# Processing: MDA | BCA | START:2016-05-04 | END: 2016-05-10
# Processing: MDA | BCA | START:2016-05-11 | END: 2016-05-17
# Processing: MDA | BCA | START:2016-05-18 | END: 2016-05-24
# Processing: MDA | BCA | START:2016-05-25 | END: 2016-05-31
# Processing: MDA | BCA | START:2016-06-01 | END: 2016-06-07
# Processing: MDA | BCA | START:2016-06-08 | END: 2016-06-14
# Processing: MDA | BCA | START:2016-06-15 | END: 2016-06-21
# Processing: MDA | BCA | START:2016-06-22 | END: 2016-06-28
# Processing: MDA | BCA | START:2016-06-29 | END: 2016-07-05
# Processing: MDA | BCA | START:2016-07-06 | END: 2016-07-12
# Processing: MDA | BCA | START:2016-07-13 | END: 2016-07-19
# Processing: MDA | BCA | START:2016-07-20 | END: 2016-07-26
# Processing: MDA | BCA | START:2016-07-27 | END: 2016-08-02
# Processing: MDA | BCA | START:2016-08-03 | END: 2016-08-09
# Processing: MDA | BCA | START:2016-08-10 | END: 2016-08-16
# Processing: MDA | BCA | START:2016-08-17 | END: 2016-08-23
# Processing: MDA | BCA | START:2016-08-24 | END: 2016-08-30
# Processing: MDA | BCA | START:2016-08-31 | END: 2016-09-06
# Processing: MDA | BCA | START:2016-09-07 | END: 2016-09-13
# Processing: MDA | BCA | START:2016-09-14 | END: 2016-09-20
# Processing: MDA | BCA | START:2016-09-21 | END: 2016-09-27
# Processing: MDA | BCA | START:2016-09-28 | END: 2016-10-04
# Processing: MDA | BCA | START:2016-10-05 | END: 2016-10-11
# Processing: MDA | BCA | START:2016-10-12 | END: 2016-10-18
# Processing: MDA | BCA | START:2016-10-19 | END: 2016-10-25
# Processing: MDA | BCA | START:2016-10-26 | END: 2016-11-01
# Processing: MDA | BCA | START:2016-11-02 | END: 2016-11-08
# Processing: MDA | BCA | START:2016-11-09 | END: 2016-11-15
# Processing: MDA | BCA | START:2016-11-16 | END: 2016-11-22
# Processing: MDA | BCA | START:2016-11-23 | END: 2016-11-29
# Processing: MDA | BCA | START:2016-11-30 | END: 2016-12-06
# Processing: MDA | BCA | START:2016-12-07 | END: 2016-12-13
# Processing: MDA | BCA | START:2016-12-14 | END: 2016-12-20
# Processing: MDA | BCA | START:2016-12-21 | END: 2016-12-27
# Processing: MDA | BCA | START:2016-12-28 | END: 2017-01-03
# Processing: MDA | BCA | START:2017-01-04 | END: 2017-01-10
# Processing: MDA | BCA | START:2017-01-11 | END: 2017-01-17
# Processing: MDA | BCA | START:2017-01-18 | END: 2017-01-24
# Processing: MDA | BCA | START:2017-01-25 | END: 2017-01-31
# Processing: MDA | BCA | START:2017-02-01 | END: 2017-02-07
# Processing: MDA | BCA | START:2017-02-08 | END: 2017-02-14
# Processing: MDA | BCA | START:2017-02-15 | END: 2017-02-21
# Processing: MDA | BCA | START:2017-02-22 | END: 2017-02-28
# Processing: MDA | BCA | START:2017-03-01 | END: 2017-03-07
# Processing: MDA | BCA | START:2017-03-08 | END: 2017-03-14
# Processing: MDA | BCA | START:2017-03-15 | END: 2017-03-21
# Processing: MDA | BCA | START:2017-03-22 | END: 2017-03-28
# Processing: MDA | BCA | START:2017-03-29 | END: 2017-04-04
# Processing: MDA | BCA | START:2017-04-05 | END: 2017-04-11
# Processing: MDA | BCA | START:2017-04-12 | END: 2017-04-18
# Processing: MDA | BCA | START:2017-04-19 | END: 2017-04-25
# Processing: MDA | BCA | START:2017-04-26 | END: 2017-05-02
# Processing: MDA | BCA | START:2017-05-03 | END: 2017-05-09
# Processing: MDA | BCA | START:2017-05-10 | END: 2017-05-16
# Processing: MDA | BCA | START:2017-05-17 | END: 2017-05-23
# Processing: MDA | BCA | START:2017-05-24 | END: 2017-05-30
# Processing: MDA | BCA | START:2017-05-31 | END: 2017-06-06
# Processing: MDA | BCA | START:2017-06-07 | END: 2017-06-13
# Processing: MDA | BCA | START:2017-06-14 | END: 2017-06-20
# Processing: MDA | BCA | START:2017-06-21 | END: 2017-06-27
# Processing: MDA | BCA | START:2017-06-28 | END: 2017-07-04
# Processing: MDA | BCA | START:2017-07-05 | END: 2017-07-11
# Processing: MDA | BCA | START:2017-07-12 | END: 2017-07-18
# Processing: MDA | BCA | START:2017-07-19 | END: 2017-07-25
# Processing: MDA | BCA | START:2017-07-26 | END: 2017-08-01
# Processing: MDA | BCA | START:2017-08-02 | END: 2017-08-08
# Processing: MDA | BCA | START:2017-08-09 | END: 2017-08-15
# Processing: MDA | BCA | START:2017-08-16 | END: 2017-08-22
# Processing: MDA | BCA | START:2017-08-23 | END: 2017-08-29
# Processing: MDA | BCA | START:2017-08-30 | END: 2017-09-05
# Processing: MDA | BCA | START:2017-09-06 | END: 2017-09-12
# Processing: MDA | BCA | START:2017-09-13 | END: 2017-09-19
# Processing: MDA | BCA | START:2017-09-20 | END: 2017-09-26
# Processing: MDA | BCA | START:2017-09-27 | END: 2017-10-03
# Processing: MDA | BCA | START:2017-10-04 | END: 2017-10-10
# Processing: MDA | BCA | START:2017-10-11 | END: 2017-10-17
# Processing: MDA | BCA | START:2017-10-18 | END: 2017-10-24
# Processing: MDA | BCA | START:2017-10-25 | END: 2017-10-31
# Processing: MDA | BCA | START:2017-11-01 | END: 2017-11-07
# Processing: MDA | BCA | START:2017-11-08 | END: 2017-11-14
# Processing: MDA | BCA | START:2017-11-15 | END: 2017-11-21
# Processing: MDA | BCA | START:2017-11-22 | END: 2017-11-28
# Processing: MDA | BCA | START:2017-11-29 | END: 2017-12-05
# Processing: MDA | BCA | START:2017-12-06 | END: 2017-12-12
# Processing: MDA | BCA | START:2017-12-13 | END: 2017-12-19
# Processing: MDA | BCA | START:2017-12-20 | END: 2017-12-26
# Processing: MDA | BCA | START:2017-12-27 | END: 2018-01-02
# Processing: MDA | BCA | START:2018-01-03 | END: 2018-01-09
# Processing: MDA | BCA | START:2018-01-10 | END: 2018-01-16
# Processing: MDA | BCA | START:2018-01-17 | END: 2018-01-23
# Processing: MDA | BCA | START:2018-01-24 | END: 2018-01-30
# Processing: MDA | BCA | START:2018-01-31 | END: 2018-02-06
# Processing: MDA | BCA | START:2018-02-07 | END: 2018-02-13
# Processing: MDA | BCA | START:2018-02-14 | END: 2018-02-20
# Processing: MDA | BCA | START:2018-02-21 | END: 2018-02-27
# Processing: MDA | BCA | START:2018-02-28 | END: 2018-03-06
# Processing: MDA | BCA | START:2018-03-07 | END: 2018-03-13
# Processing: MDA | BCA | START:2018-03-14 | END: 2018-03-20
# Processing: MDA | BCA | START:2018-03-21 | END: 2018-03-27
# Processing: MDA | BCA | START:2018-03-28 | END: 2018-04-03
# Processing: MDA | BCA | START:2018-04-04 | END: 2018-04-10
# Processing: MDA | BCA | START:2018-04-11 | END: 2018-04-17
# Processing: MDA | BCA | START:2018-04-18 | END: 2018-04-24
# Processing: MDA | BCA | START:2018-04-25 | END: 2018-05-01
# Processing: MDA | BCA | START:2018-05-02 | END: 2018-05-08
# Processing: MDA | BCA | START:2018-05-09 | END: 2018-05-15
# Processing: MDA | BCA | START:2018-05-16 | END: 2018-05-22
# Processing: MDA | BCA | START:2018-05-23 | END: 2018-05-29
# Processing: MDA | BCA | START:2018-05-30 | END: 2018-06-05
# Processing: MDA | BCA | START:2018-06-06 | END: 2018-06-12
# Processing: MDA | BCA | START:2018-06-13 | END: 2018-06-19
# Processing: MDA | BCA | START:2018-06-20 | END: 2018-06-26
# Processing: MDA | BCA | START:2018-06-27 | END: 2018-07-03
# Processing: MDA | BCA | START:2018-07-04 | END: 2018-07-10
# Processing: MDA | BCA | START:2018-07-11 | END: 2018-07-17
# Processing: MDA | BCA | START:2018-07-18 | END: 2018-07-24
# Processing: MDA | BCA | START:2018-07-25 | END: 2018-07-31
# Processing: MDA | BCA | START:2018-08-01 | END: 2018-08-07
# Processing: MDA | BCA | START:2018-08-08 | END: 2018-08-14
# Processing: MDA | BCA | START:2018-08-15 | END: 2018-08-21
# Processing: MDA | BCA | START:2018-08-22 | END: 2018-08-28
# Processing: MDA | BCA | START:2018-08-29 | END: 2018-09-04
# Processing: MDA | BCA | START:2018-09-05 | END: 2018-09-11
# Processing: MDA | BCA | START:2018-09-12 | END: 2018-09-18
# Processing: MDA | BCA | START:2018-09-19 | END: 2018-09-25
# Processing: MDA | BCA | START:2018-09-26 | END: 2018-10-02
# Processing: MDA | BCA | START:2018-10-03 | END: 2018-10-09
# Processing: MDA | BCA | START:2018-10-10 | END: 2018-10-16
# Processing: MDA | BCA | START:2018-10-17 | END: 2018-10-23
# Processing: MDA | BCA | START:2018-10-24 | END: 2018-10-30
# Processing: MDA | BCA | START:2018-10-31 | END: 2018-11-06
# Processing: MDA | BCA | START:2018-11-07 | END: 2018-11-13
# Processing: MDA | BCA | START:2018-11-14 | END: 2018-11-20
# Processing: MDA | BCA | START:2018-11-21 | END: 2018-11-27
# Processing: MDA | BCA | START:2018-11-28 | END: 2018-12-04
# Processing: MDA | BCA | START:2018-12-05 | END: 2018-12-11
# Processing: MDA | BCA | START:2018-12-12 | END: 2018-12-18
# Processing: MDA | BCA | START:2018-12-19 | END: 2018-12-25
# Processing: MDA | BCA | START:2018-12-26 | END: 2019-01-01
# Processing: MDA | BCA | START:2019-01-02 | END: 2019-01-08
# Processing: MDA | BCA | START:2019-01-09 | END: 2019-01-15
# Processing: MDA | BCA | START:2019-01-16 | END: 2019-01-22
# Processing: MDA | BCA | START:2019-01-23 | END: 2019-01-29
# Processing: MDA | BCA | START:2019-01-30 | END: 2019-02-05
# Processing: MDA | BCA | START:2019-02-06 | END: 2019-02-12
# Processing: MDA | BCA | START:2019-02-13 | END: 2019-02-19
# Processing: MDA | BCA | START:2019-02-20 | END: 2019-02-26
# Processing: MDA | BCA | START:2019-02-27 | END: 2019-03-05
# Processing: MDA | BCA | START:2019-03-06 | END: 2019-03-12
# Processing: MDA | BCA | START:2019-03-13 | END: 2019-03-19
# Processing: MDA | BCA | START:2019-03-20 | END: 2019-03-26
# Processing: MDA | BCA | START:2019-03-27 | END: 2019-04-02
# Processing: MDA | BCA | START:2019-04-03 | END: 2019-04-09
# Processing: MDA | BCA | START:2019-04-10 | END: 2019-04-16
# Processing: MDA | BCA | START:2019-04-17 | END: 2019-04-23
# Processing: MDA | BCA | START:2019-04-24 | END: 2019-04-30
# Processing: MDA | BCA | START:2019-05-01 | END: 2019-05-01
# -----------------------------------------------------------------------------------------
#                          EXTRACTION PROCESS FINISHED
# -----------------------------------------------------------------------------------------

# %%
#Create Pandas Data Frame
MT_DF_MDA = pd.DataFrame({
    "SYSTEM":"BCA",
    "ZONE":Zonas_MDA,
    "DATE":Fechas_MDA,
    "HOUR":Horas_MDA,
    "MDA LMP":pz_MDA,
    "MDA ENERGY COST":pz_ene_MDA,
    "MDA LOSSES COST":pz_per_MDA,
    "MDA CONGESTION COST":pz_cng_MDA,
})
MT_DF_MDA= MT_DF_MDA.sort_values(["ZONE","DATE"], ascending=[True,True])
MT_DF_MDA= MT_DF_MDA[['SYSTEM', 'ZONE', 'DATE', 'HOUR', 'MDA LMP', 'MDA ENERGY COST', 'MDA LOSSES COST',
                     'MDA CONGESTION COST']]
#Drop null values
BCA_DF_MDA=MT_DF_MDA.dropna()

#Create CSV file
BCA_DF_MDA.to_csv("BCA_MDA_ZONALPRICES.csv", index=False) 

print("----------------------------------------------------------------------------")
print("              Saved clean data as BCA_MDA_ZONALPRICES.csv                   ")
print("----------------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------------
#               Saved clean data as BCA_MDA_ZONALPRICES.csv
# ----------------------------------------------------------------------------

# %%
#Check what values where missing

missing_values= np.count_nonzero(MT_DF_MDA.isnull())
print("Number of missing values: ")
print(str(missing_values))

#Which zones,dates and hours are missing
rows_missing_LMP_data = list(MT_DF_MDA.loc[pd.isnull(MT_DF_MDA["MDA LMP"]), :].index)
rows_missing_Energy_data = list(MT_DF_MDA.loc[pd.isnull(MT_DF_MDA["MDA ENERGY COST"]), :].index)
rows_missing_Losses_data = list(MT_DF_MDA.loc[pd.isnull(MT_DF_MDA["MDA LOSSES COST"]), :].index)
rows_missing_Congestion_data = list(MT_DF_MDA.loc[pd.isnull(MT_DF_MDA["MDA CONGESTION COST"]), :].index)

indices = rows_missing_LMP_data + rows_missing_Energy_data + rows_missing_Losses_data + rows_missing_Congestion_data

#Avoid having the same row index twice
indices=list(set(indices))
indices.sort()

print("Index of zones that are missing data (DATE, HOUR, MDA LMP, MDA ENERGY COST, MDA LOSSES COST and MDA CONGESTION COST):")
print("")

j= 1
for index in indices:
    print(str(j) + "- Index:" + str(index) + " - Zone: "+ MT_DF_MDA.iloc[index]['ZONE'] + "|| Estimated Date:" +\
          MT_DF_MDA.iloc[index-1]['DATE'] + "|| Estimated Time:" + str(int(MT_DF_MDA.iloc[index+1]['HOUR'])- 1))  
    print("------------------------------------------------------------")
    j = j +1
    
print("")
print("As observed above, each zone is missing four rows of data. Notably, missing data seems to take place at the same hour")
print("for each zone but in four different days. Missing data usually takes places in the same month or dates only one or two")
print("weeks apart.")
# Out:
# Number of missing values:
# 96
# Index of zones that are missing data (DATE, HOUR, MDA LMP, MDA ENERGY COST, MDA LOSSES COST and MDA CONGESTION COST):
#
# 1- Index:4199 - Zone: ENSENADA|| Estimated Date:2016-07-19|| Estimated Time:1
# ------------------------------------------------------------
# 2- Index:4367 - Zone: ENSENADA|| Estimated Date:2016-07-26|| Estimated Time:1
# ------------------------------------------------------------
# 3- Index:4535 - Zone: ENSENADA|| Estimated Date:2016-08-02|| Estimated Time:1
# ------------------------------------------------------------
# 4- Index:4703 - Zone: ENSENADA|| Estimated Date:2016-08-09|| Estimated Time:1
# ------------------------------------------------------------
# 5- Index:39143 - Zone: MEXICALI|| Estimated Date:2017-04-11|| Estimated Time:2
# ------------------------------------------------------------
# 6- Index:39311 - Zone: MEXICALI|| Estimated Date:2017-04-18|| Estimated Time:2
# ------------------------------------------------------------
# 7- Index:39479 - Zone: MEXICALI|| Estimated Date:2017-04-25|| Estimated Time:2
# ------------------------------------------------------------
# 8- Index:39647 - Zone: MEXICALI|| Estimated Date:2017-05-02|| Estimated Time:2
# ------------------------------------------------------------
# 9- Index:74087 - Zone: SANLUIS|| Estimated Date:2018-01-01|| Estimated Time:2
# ------------------------------------------------------------
# 10- Index:74255 - Zone: SANLUIS|| Estimated Date:2018-01-08|| Estimated Time:2
# ------------------------------------------------------------
# 11- Index:74423 - Zone: SANLUIS|| Estimated Date:2018-01-15|| Estimated Time:2
# ------------------------------------------------------------
# 12- Index:74591 - Zone: SANLUIS|| Estimated Date:2018-01-22|| Estimated Time:2
# ------------------------------------------------------------
# 13- Index:109031 - Zone: TIJUANA|| Estimated Date:2018-09-23|| Estimated Time:3
# ------------------------------------------------------------
# 14- Index:109199 - Zone: TIJUANA|| Estimated Date:2018-09-30|| Estimated Time:3
# ------------------------------------------------------------
# 15- Index:109367 - Zone: TIJUANA|| Estimated Date:2018-10-07|| Estimated Time:3
# ------------------------------------------------------------
# 16- Index:109535 - Zone: TIJUANA|| Estimated Date:2018-10-14|| Estimated Time:3
# ------------------------------------------------------------
#
# As observed above, each zone is missing four rows of data. Notably, missing data seems to take place at the same hour
# for each zone but in four different days. Missing data usually takes places in the same month or dates only one or two
# weeks apart.
